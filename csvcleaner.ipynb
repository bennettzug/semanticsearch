# %%
import pandas as pd

# %%
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/course-catalog.csv")

# %%
df
# Out:
#        Year    Term YearTerm Subject  Number                          Name  \
# 0      2024  Spring  2024-sp     AAS     100  Intro Asian American Studies
# 1      2024  Spring  2024-sp     AAS     100  Intro Asian American Studies
# 2      2024  Spring  2024-sp     AAS     100  Intro Asian American Studies
# 3      2024  Spring  2024-sp     AAS     100  Intro Asian American Studies
# 4      2024  Spring  2024-sp     AAS     100  Intro Asian American Studies
# ...     ...     ...      ...     ...     ...                           ...
# 11898  2024  Spring  2024-sp    WRIT     303          Writing Across Media
# 11899  2024  Spring  2024-sp    WRIT     303          Writing Across Media
# 11900  2024  Spring  2024-sp    YDSH     102          Beginning Yiddish II
# 11901  2024  Spring  2024-sp    YDSH     102          Beginning Yiddish II
# 11902  2024  Spring  2024-sp    ZULU     202            Elementary Zulu II
#
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Term', 'YearTerm', 'Subject', 'Number', 'Name', 'Description',
#        'Credit Hours', 'Section Info', 'Degree Attributes',
#        'Schedule Information', 'CRN', 'Section', 'Status Code', 'Part of Term',
#        'Section Title', 'Section Credit Hours', 'Section Status',
#        'Enrollment Status', 'Type', 'Type Code', 'Start Time', 'End Time',
#        'Days of Week', 'Room', 'Building', 'Instructors'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Year                     int64
# Term                    object
# YearTerm                object
# Subject                 object
# Number                   int64
# Name                    object
# Description             object
# Credit Hours            object
# Section Info            object
# Degree Attributes       object
# Schedule Information    object
# CRN                      int64
# Section                 object
# Status Code             object
# Part of Term            object
# Section Title           object
# Section Credit Hours    object
# Section Status          object
# Enrollment Status       object
# Type                    object
# Type Code               object
# Start Time              object
# End Time                object
# Days of Week            object
# Room                    object
# Building                object
# Instructors             object
# dtype: object

# %%
df2 = df.copy()

# %%
df2
# Out:
#        Year    Term YearTerm Subject  Number                          Name  \
# 0      2024  Spring  2024-sp     AAS     100  Intro Asian American Studies
# 1      2024  Spring  2024-sp     AAS     100  Intro Asian American Studies
# 2      2024  Spring  2024-sp     AAS     100  Intro Asian American Studies
# 3      2024  Spring  2024-sp     AAS     100  Intro Asian American Studies
# 4      2024  Spring  2024-sp     AAS     100  Intro Asian American Studies
# ...     ...     ...      ...     ...     ...                           ...
# 11898  2024  Spring  2024-sp    WRIT     303          Writing Across Media
# 11899  2024  Spring  2024-sp    WRIT     303          Writing Across Media
# 11900  2024  Spring  2024-sp    YDSH     102          Beginning Yiddish II
# 11901  2024  Spring  2024-sp    YDSH     102          Beginning Yiddish II
# 11902  2024  Spring  2024-sp    ZULU     202            Elementary Zulu II
#
# ...

# %%
df2 = df2.drop_duplicates(subset=["Subject", "Number", "Name", "Description", "Credit Hours"])

# %%
df2
# Out:
#        Year    Term YearTerm Subject  Number                             Name  \
# 0      2024  Spring  2024-sp     AAS     100     Intro Asian American Studies
# 11     2024  Spring  2024-sp     AAS     200             U.S. Race and Empire
# 12     2024  Spring  2024-sp     AAS     201  US Racial &amp; Ethnic Politics
# 15     2024  Spring  2024-sp     AAS     275          The Politics of Fashion
# 23     2024  Spring  2024-sp     AAS     283           Asian American History
# ...     ...     ...      ...     ...     ...                              ...
# 11893  2024  Spring  2024-sp    WLOF     404            Intermediate Wolof II
# 11894  2024  Spring  2024-sp    WLOF     406                Advanced Wolof II
# 11895  2024  Spring  2024-sp    WRIT     303             Writing Across Media
# 11900  2024  Spring  2024-sp    YDSH     102             Beginning Yiddish II
# 11902  2024  Spring  2024-sp    ZULU     202               Elementary Zulu II
#
# ...

# %%
df2 = df2.filter(items=["Subject", "Number", "Name", "Description", "Credit Hours"])

# %%
df2
# Out:
#       Subject  Number                             Name  \
# 0         AAS     100     Intro Asian American Studies
# 11        AAS     200             U.S. Race and Empire
# 12        AAS     201  US Racial &amp; Ethnic Politics
# 15        AAS     275          The Politics of Fashion
# 23        AAS     283           Asian American History
# ...       ...     ...                              ...
# 11893    WLOF     404            Intermediate Wolof II
# 11894    WLOF     406                Advanced Wolof II
# 11895    WRIT     303             Writing Across Media
# 11900    YDSH     102             Beginning Yiddish II
# 11902    ZULU     202               Elementary Zulu II
#
#                                              Description Credit Hours
# 0      Interdisciplinary introduction to the basic co...     3 hours.
# 11     Invites students to examine histories and narr...     3 hours.
# 12     Same as AFRO 201, LLS 201, and PS 201. See PS ...     3 hours.
# ...

# %%
df2.to_csv("course-catalog-filtered.csv", index=False)
